# %% [markdown]
# ## 获取账户信息

# %%
import nest_asyncio
nest_asyncio.apply()

from ib_insync import *

import pandas as pd

contract = "SOXL"
# 初始化并连接到 TWS/Gateway
ib = IB()
ib.connect('127.0.0.1', 7496, clientId=3)
# Out:
# <IB connected to 127.0.0.1:7496 clientId=3>

# %%
account_summary = ib.accountSummary()
account_summary
# 提取净资产和可用资金
# net_liquidation = account_summary.loc['NetLiquidation', 'value']  # 净资产
# available_funds = account_summary.loc['AvailableFunds', 'value']  # 可用资金

# print(f"净资产 (Net Liquidation): {net_liquidation}")
# print(f"可用资金 (Available Funds): {available_funds}")
# Out:
#        account                    tag       value currency modelCode
# 0    U19892138            AccountType  INDIVIDUAL
# 1    U19892138                Cushion    0.690505
# 2    U19892138     DayTradesRemaining          -1
# 3    U19892138  DayTradesRemainingT+1          -1
# 4    U19892138  DayTradesRemainingT+2          -1
# ..         ...                    ...         ...      ...       ...
# 125        All          FxCashBalance        0.00     BASE
# 126        All         AccountOrGroup         All     BASE
# 127        All           RealCurrency        BASE     BASE
# 128        All      IssuerOptionValue        0.00     BASE
# 129        All         Cryptocurrency                 BASE
#
# [130 rows x 5 columns]
